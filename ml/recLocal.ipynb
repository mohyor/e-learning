# %%
import pandas as pd
import numpy as np

# Make numpy values easier to read.
np.set_printoptions(precision=3, suppress=True)

#import tensorflow as tf
#from tensorflow.keras import layers

# %%
users_data = pd.read_csv(r'C:\Users\moyo\OneDrive\Documents\Codes\Web\Node\e-learning\ml\datasets\users.csv', delimiter=';')
print('DataFrame shape is: ', users_data.shape)
users_data.head()
# Out:
# DataFrame shape is:  (5, 1)
#   __v,_id,courses,createdAt,email,name,password,picture,role,updatedAt
# 0  0,6214e2ac0feccaf7d266ebef,,2022-02-22T13:18:3...
# 1  0,6214e3360feccaf7d266ebf4,"[{""$oid"":""62162...
# 2  0,62371761ae894c9bdca29a15,"[{""$oid"":""62414...
# 3  0,624577d0e92ce9961959d77b,"[{""$oid"":""62417...
# 4  0,624578b6bda61dc56d57ea2a,"[{""$oid"":""62458...

# %%
courses_data = pd.read_csv(r'C:\Users\moyo\OneDrive\Documents\Codes\Web\Node\e-learning\ml\datasets\courses.csv')
print(courses_data.shape)
courses_data.head()
# Out:
# (10, 15)
#    __v                       _id                  category  \
# 0    2  62414201b28d80ff20172fe7  62413cdeb28d80ff20172fdf
# 1    2  62414353b28d80ff20172feb  62413cdeb28d80ff20172fdf
# 2    2  62414655817647df4ab0ba2a  62413cdeb28d80ff20172fdf
# 3    2  62417498817647df4ab0ba48  62413cdeb28d80ff20172fdf
# 4    2  62458218569e0aeca6d5645a  62413cdeb28d80ff20172fdf
#
#                   createdAt  credits  \
# 0  2022-03-28T05:05:05.031Z        2
# 1  2022-03-28T05:10:43.914Z        2
# 2  2022-03-28T05:23:33.991Z        2
# 3  2022-03-28T08:40:56.973Z        3
# 4  2022-03-31T10:27:36.996Z        2
#
#                                          description  \
# 0  General classification of materials based on a...
# 1  Stresses and strains due to loading and temper...
# 2  Definition of fluid mechanics. Areas of applic...
# 3  The electric field of charge, electric conduct...
# 4   Two state system; converting number system, ...
#
# ...
